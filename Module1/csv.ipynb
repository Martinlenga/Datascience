# %% [markdown]
# name, age, city
# Martin, 20, Nairobi
# Tete, 21, Mombasa
# Sharly, 21, Machakos

# %%
import csv 

with open("details.csv", "r") as file:
    stds = csv.reader(file)

    for std in stds:
        print(std)
# Out:
# ['name', ' age', ' city']
# ['Martin', ' 20', ' Nairobi']
# ['Tete', ' 21', ' Mombasa']
# ['Sharly', ' 21', ' Machakos']
